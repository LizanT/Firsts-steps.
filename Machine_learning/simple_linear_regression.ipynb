# %% [markdown]
# # Simple Linear Regression.

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
salary = pd.read_csv('salary_clean.csv')

# %%
salary
# Out:
#       Unnamed: 0   Age  Gender Education Level                  Job Title  \
# 0              0  32.0    male        Bachelor          Software Engineer
# 1              1  28.0  female          Master               Data Analyst
# 2              2  45.0    male             phd             Senior Manager
# 3              3  36.0  female        Bachelor            Sales Associate
# 4              4  52.0    male          Master                   Director
# ...          ...   ...     ...             ...                        ...
# 1779        6623  43.0  female          Master  Digital Marketing Manager
# 1780        6624  27.0    male     high school              Sales Manager
# 1781        6625  33.0  female        Bachelor      Director of Marketing
# 1782        6628  37.0    male        Bachelor             Sales Director
# 1783        6631  30.0  female        Bachelor              Sales Manager
#
#       Years of Experience    Salary
# 0                     5.0   90000.0
# ...

# %% [markdown]
# # Salary in Function Years of Experience.

# %%
plt.figure(figsize=(10,6))

plt.ylabel('Salary ($)')
plt.xlabel('Years of Experience')
plt.scatter(salary["Years of Experience"], salary["Salary"], color="pink")
plt.show()

# %% [markdown]
# # Model Creaction.

# %%
from sklearn import linear_model

regression = linear_model.LinearRegression()

# Changes into vector.
years = salary['Years of Experience'].values.reshape((-1,1))

# %% [markdown]
# # Training the model.

# %%
# Using fit, the model will train with the input and ouput values.
model = regression.fit(years, salary['Salary'])

print(f'Intercept (b) {model.intercept_}')
print(f'Slope (m) {model.coef_} ')
# Out:
# Intercept (b) 56716.38243259942
# Slope (m) [6163.21908485]

# %% [markdown]
# # Prediction with a new vector.

# %%
# People who has 7 , 13, 15, 21 years of experience, their salary will be...

values = [[5],[13],[15],[30]]

predict_values = model.predict(values)

print(f'A person who has 7, 13, 15 or 21 years of experience will be earn : {predict_values}')
# Out:
# A person who has 7, 13, 15 or 21 years of experience will be earn : [ 87532.47785683 136838.2305356  149164.66870529 241612.95497798]

# %% [markdown]
# # Plot prediction into dataframe chart.

# %%
plt.figure(figsize=(10,6))

plt.scatter(values, predict_values, color='green', s=50, zorder=10)
plt.plot(values, predict_values, color='black')

# Dataframe chart
plt.ylabel('Salary ($)')
plt.xlabel('Years of Experience')
plt.scatter(salary["Years of Experience"], salary["Salary"], color="pink")
plt.show()
